# %% [markdown]
# # ECG Walsh-Hadamard SaSiDa verification run
#
# Run this notebook in Google Colab after uploading/cloning the repository.

# %%
# !pip -q install -r requirements.txt

# %%
# !python run_demo.py --outdir results_colab

# %%
import pandas as pd
pd.read_csv('results_colab/summary_metrics.csv')
